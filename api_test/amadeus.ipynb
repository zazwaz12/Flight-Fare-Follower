# %%
import requests

#to read the environment variables from .env
import os
from dotenv import load_dotenv
load_dotenv()
API_KEY = os.environ.get("API_KEY")
API_SECRET_KEY = os.environ.get("API_SECRET_KEY")

# %%
url = 'https://test.api.amadeus.com/v1/security/oauth2/token'
headers = {"Content-Type": "application/x-www-form-urlencoded"}
params = {"grant_type": "client_credentials", 
          "client_id": API_KEY, 
          "client_secret": API_SECRET_KEY}
response = requests.post(url, data=params, headers=headers)
access_token = response.json()['access_token']

# %%
#Response for the return flight
base_url = "https://test.api.amadeus.com/v1/shopping/flight-dates"
headers = {'Authorization': f'Bearer {access_token}'}
params = {
    "origin": "SYD", 
    "destination": "LAX", 
    "departureDate": "2024-02-01,2024-07-01", 
    "duration": 12, 
    "oneWay": False, 
    "viewBy": "DATE", 
    # "nonStop": True
}
response = requests.get(base_url, params=params, headers=headers)
round_way_trips = response.json()['data']

# %%
# List to store the results for different durations
return_flight_results = []

# Iterate over durations (9 to 15 days)
for duration in range(9, 15):
    params = {
        "origin": "SYD",
        "destination": "LAX",
        "departureDate": "2024-02-01,2024-07-01",
        "duration": duration,
        "oneWay": False,
        "viewBy": "DATE",
        # "nonStop": True
    }

    # Make the API request
    response = requests.get(base_url, params=params, headers=headers)

    # Extract relevant information and append to the results list
    round_way_trips = response.json()['data']
    return_results_for_duration = [
        (entry['origin'], entry['destination'], entry['departureDate'], entry['price']['total'])
        for entry in round_way_trips
    ]

    # Append the results to the main list
    return_flight_results.append(return_results_for_duration)

#return_flight_results shows a list of lists of flights for each duration from 9 days to 15 days
#return_flight_results
# Out:
# [[('SYD', 'LAX', '2024-02-16', '1014.86'),
#   ('SYD', 'LAX', '2024-02-13', '1014.86'),
#   ('SYD', 'LAX', '2024-02-18', '1014.86'),
#   ('SYD', 'LAX', '2024-04-27', '1022.76'),
#   ('SYD', 'LAX', '2024-05-03', '1022.76'),
#   ('SYD', 'LAX', '2024-02-17', '1022.76'),
#   ('SYD', 'LAX', '2024-06-19', '1022.76'),
#   ('SYD', 'LAX', '2024-02-08', '1022.76'),
#   ('SYD', 'LAX', '2024-02-20', '1022.76'),
#   ('SYD', 'LAX', '2024-05-24', '1022.76'),
#   ('SYD', 'LAX', '2024-02-15', '1022.76'),
#   ('SYD', 'LAX', '2024-03-07', '1022.76'),
#   ('SYD', 'LAX', '2024-05-31', '1022.76'),
#   ('SYD', 'LAX', '2024-06-01', '1022.76'),
#   ('SYD', 'LAX', '2024-05-04', '1022.76'),
#   ('SYD', 'LAX', '2024-02-10', '1022.76'),
#   ('SYD', 'LAX', '2024-03-09', '1022.76'),
#   ('SYD', 'LAX', '2024-04-28', '1022.76'),
#   ('SYD', 'LAX', '2024-05-02', '1022.76'),
#   ('SYD', 'LAX', '2024-05-06', '1022.76'),
#   ('SYD', 'LAX', '2024-05-08', '1022.76'),
#   ('SYD', 'LAX', '2024-05-10', '1022.76'),
#   ('SYD', 'LAX', '2024-05-13', '1022.76'),
#   ('SYD', 'LAX', '2024-05-15', '1022.76'),
#   ('SYD', 'LAX', '2024-05-16', '1022.76'),
#   ('SYD', 'LAX', '2024-05-19', '1022.76'),
#   ('SYD', 'LAX', '2024-05-22', '1022.76'),
#   ('SYD', 'LAX', '2024-05-26', '1022.76'),
#   ('SYD', 'LAX', '2024-05-29', '1022.76'),
#   ('SYD', 'LAX', '2024-06-06', '1022.76'),
#   ('SYD', 'LAX', '2024-06-12', '1022.76'),
#   ('SYD', 'LAX', '2024-06-13', '1022.76'),
#   ('SYD', 'LAX', '2024-06-14', '1022.76'),
#   ('SYD', 'LAX', '2024-05-14', '1022.76'),
#   ('SYD', 'LAX', '2024-05-28', '1022.76'),
#   ('SYD', 'LAX', '2024-02-04', '1022.76'),
#   ('SYD', 'LAX', '2024-02-14', '1022.76'),
#   ('SYD', 'LAX', '2024-03-04', '1022.76'),
#   ('SYD', 'LAX', '2024-03-10', '1022.76'),
#   ('SYD', 'LAX', '2024-06-02', '1022.76'),
#   ('SYD', 'LAX', '2024-05-20', '1022.76'),
#   ('SYD', 'LAX', '2024-06-05', '1022.76'),
#   ('SYD', 'LAX', '2024-02-06', '1022.76'),
#   ('SYD', 'LAX', '2024-06-08', '1022.76'),
#   ('SYD', 'LAX', '2024-05-11', '1022.76'),
#   ('SYD', 'LAX', '2024-05-17', '1022.76'),
#   ('SYD', 'LAX', '2024-06-10', '1022.76'),
#   ('SYD', 'LAX', '2024-03-18', '1022.76'),
#   ('SYD', 'LAX', '2024-06-09', '1022.76'),
#   ('SYD', 'LAX', '2024-06-15', '1022.76'),
#   ('SYD', 'LAX', '2024-04-05', '1022.76'),
#   ('SYD', 'LAX', '2024-04-02', '1022.76'),
#   ('SYD', 'LAX', '2024-03-01', '1022.76'),
#   ('SYD', 'LAX', '2024-03-31', '1022.76'),
#   ('SYD', 'LAX', '2024-03-08', '1022.76'),
#   ('SYD', 'LAX', '2024-04-06', '1022.76'),
#   ('SYD', 'LAX', '2024-04-04', '1022.76'),
#   ('SYD', 'LAX', '2024-03-15', '1022.76'),
#   ('SYD', 'LAX', '2024-06-16', '1022.76'),
#   ('SYD', 'LAX', '2024-05-18', '1022.76'),
#   ('SYD', 'LAX', '2024-02-03', '1022.76'),
#   ('SYD', 'LAX', '2024-05-23', '1022.76'),
#   ('SYD', 'LAX', '2024-05-07', '1022.76'),
#   ('SYD', 'LAX', '2024-02-02', '1022.76'),
#   ('SYD', 'LAX', '2024-03-06', '1022.76'),
#   ('SYD', 'LAX', '2024-03-02', '1022.76'),
#   ('SYD', 'LAX', '2024-03-16', '1022.76'),
#   ('SYD', 'LAX', '2024-04-26', '1022.76'),
#   ('SYD', 'LAX', '2024-06-17', '1022.76'),
#   ('SYD', 'LAX', '2024-06-04', '1022.76'),
#   ('SYD', 'LAX', '2024-03-13', '1022.76'),
#   ('SYD', 'LAX', '2024-04-29', '1022.76'),
#   ('SYD', 'LAX', '2024-03-14', '1022.76'),
#   ('SYD', 'LAX', '2024-05-01', '1022.76'),
#   ('SYD', 'LAX', '2024-03-05', '1022.76'),
#   ('SYD', 'LAX', '2024-05-05', '1022.76'),
#   ('SYD', 'LAX', '2024-04-30', '1022.76'),
#   ('SYD', 'LAX', '2024-05-09', '1022.76'),
#   ('SYD', 'LAX', '2024-05-12', '1022.76'),
#   ('SYD', 'LAX', '2024-05-30', '1022.76'),
#   ('SYD', 'LAX', '2024-05-27', '1022.76'),
#   ('SYD', 'LAX', '2024-06-03', '1022.76'),
#   ('SYD', 'LAX', '2024-06-07', '1022.76'),
#   ('SYD', 'LAX', '2024-04-01', '1022.76'),
#   ('SYD', 'LAX', '2024-02-19', '1022.76'),
#   ('SYD', 'LAX', '2024-02-23', '1022.76'),
#   ('SYD', 'LAX', '2024-03-17', '1022.76'),
#   ('SYD', 'LAX', '2024-04-03', '1022.76'),
#   ('SYD', 'LAX', '2024-02-05', '1022.76'),
#   ('SYD', 'LAX', '2024-03-11', '1022.76'),
#   ('SYD', 'LAX', '2024-05-21', '1022.76'),
#   ('SYD', 'LAX', '2024-06-11', '1022.76'),
#   ('SYD', 'LAX', '2024-06-18', '1022.76'),
#   ('SYD', 'LAX', '2024-02-07', '1022.76'),
#   ('SYD', 'LAX', '2024-02-21', '1022.76'),
#   ('SYD', 'LAX', '2024-02-09', '1022.76'),
#   ('SYD', 'LAX', '2024-02-11', '1022.76'),
#   ('SYD', 'LAX', '2024-02-22', '1022.76'),
#   ('SYD', 'LAX', '2024-02-25', '1022.76'),
#   ('SYD', 'LAX', '2024-03-20', '1022.76'),
#   ('SYD', 'LAX', '2024-02-27', '1022.76'),
#   ('SYD', 'LAX', '2024-03-12', '1022.76'),
#   ('SYD', 'LAX', '2024-03-19', '1022.76'),
#   ('SYD', 'LAX', '2024-06-22', '1121.76'),
#   ('SYD', 'LAX', '2024-06-23', '1121.76'),
#   ('SYD', 'LAX', '2024-06-24', '1121.76'),
#   ('SYD', 'LAX', '2024-06-25', '1121.76'),
#   ('SYD', 'LAX', '2024-06-26', '1121.76'),
#   ('SYD', 'LAX', '2024-06-27', '1121.76'),
#   ('SYD', 'ONT', '2024-02-01', '1148.26'),
#   ('SYD', 'ONT', '2024-03-26', '1162.86'),
#   ('SYD', 'LAX', '2024-03-03', '1162.86'),
#   ('SYD', 'LAX', '2024-03-25', '1221.46'),
#   ('SYD', 'LAX', '2024-02-12', '1221.46'),
#   ('SYD', 'LAX', '2024-04-22', '1270.46'),
#   ('SYD', 'LAX', '2024-04-23', '1270.46'),
#   ('SYD', 'LAX', '2024-03-22', '1272.76'),
#   ('SYD', 'LAX', '2024-03-29', '1272.76'),
#   ('SYD', 'LAX', '2024-03-30', '1272.76'),
#   ('SYD', 'LAX', '2024-03-28', '1272.76'),
#   ('SYD', 'LAX', '2024-03-27', '1272.76'),
#   ('SYD', 'LAX', '2024-03-21', '1272.76'),
#   ('SYD', 'LAX', '2024-05-25', '1281.76'),
#   ('SYD', 'LAX', '2024-04-25', '1281.76'),
#   ('SYD', 'LAX', '2024-03-23', '1296.46'),
#   ('SYD', 'LAX', '2024-03-24', '1296.46'),
#   ('SYD', 'LAX', '2024-04-08', '1331.76'),
#   ('SYD', 'LAX', '2024-04-17', '1345.46'),
#   ('SYD', 'LAX', '2024-04-18', '1345.46'),
#   ('SYD', 'LAX', '2024-04-24', '1345.46'),
#   ('SYD', 'LAX', '2024-04-20', '1345.46'),
#   ('SYD', 'LAX', '2024-04-21', '1345.46'),
#   ('SYD', 'LAX', '2024-04-09', '1420.46'),
#   ('SYD', 'LAX', '2024-04-16', '1420.46'),
#   ('SYD', 'LAX', '2024-04-19', '1420.46'),
#   ('SYD', 'LAX', '2024-02-29', '1428.86'),
#   ('SYD', 'LAX', '2024-02-26', '1444.44'),
#   ('SYD', 'LAX', '2024-04-15', '1455.51'),
#   ('SYD', 'LAX', '2024-02-24', '1485.46'),
#   ('SYD', 'LAX', '2024-04-11', '1495.46'),
#   ('SYD', 'LAX', '2024-04-14', '1495.46'),
#   ('SYD', 'LAX', '2024-04-13', '1505.51'),
#   ('SYD', 'LAX', '2024-04-07', '1519.46'),
#   ('SYD', 'LAX', '2024-04-10', '1519.46'),
#   ('SYD', 'LAX', '2024-04-12', '1519.46'),
#   ('SYD', 'LAX', '2024-02-28', '1527.86'),
#   ('SYD', 'LAX', '2024-06-20', '1539.86'),
#   ('SYD', 'LAX', '2024-06-21', '1606.46'),
#   ('SYD', 'LAX', '2024-06-28', '1606.46'),
#   ('SYD', 'LAX', '2024-06-29', '1713.76'),
#   ('SYD', 'LAX', '2024-07-01', '2080.36'),
#   ('SYD', 'LAX', '2024-06-30', '2132.00')],
#  [('SYD', 'LAX', '2024-02-18', '998.26'),
#   ('SYD', 'LAX', '2024-02-04', '1014.86'),
#   ('SYD', 'LAX', '2024-02-17', '1014.86'),
#   ('SYD', 'LAX', '2024-02-20', '1014.86'),
#   ('SYD', 'LAX', '2024-02-10', '1014.86'),
#   ('SYD', 'LAX', '2024-02-11', '1014.86'),
#   ('SYD', 'ONT', '2024-06-04', '1014.86'),
#   ('SYD', 'LAX', '2024-04-27', '1022.76'),
#   ('SYD', 'LAX', '2024-05-03', '1022.76'),
#   ('SYD', 'LAX', '2024-05-18', '1022.76'),
#   ('SYD', 'LAX', '2024-02-03', '1022.76'),
#   ('SYD', 'LAX', '2024-03-09', '1022.76'),
#   ('SYD', 'LAX', '2024-04-25', '1022.76'),
#   ('SYD', 'LAX', '2024-04-28', '1022.76'),
#   ('SYD', 'LAX', '2024-05-07', '1022.76'),
#   ('SYD', 'LAX', '2024-05-14', '1022.76'),
#   ('SYD', 'LAX', '2024-05-15', '1022.76'),
#   ('SYD', 'LAX', '2024-05-21', '1022.76'),
#   ('SYD', 'LAX', '2024-05-26', '1022.76'),
#   ('SYD', 'LAX', '2024-05-28', '1022.76'),
#   ('SYD', 'LAX', '2024-06-05', '1022.76'),
#   ('SYD', 'LAX', '2024-06-12', '1022.76'),
#   ('SYD', 'LAX', '2024-06-13', '1022.76'),
#   ('SYD', 'LAX', '2024-06-14', '1022.76'),
#   ('SYD', 'LAX', '2024-04-03', '1022.76'),
#   ('SYD', 'LAX', '2024-05-13', '1022.76'),
#   ('SYD', 'LAX', '2024-03-07', '1022.76'),
#   ('SYD', 'LAX', '2024-02-12', '1022.76'),
#   ('SYD', 'LAX', '2024-03-04', '1022.76'),
#   ('SYD', 'LAX', '2024-05-31', '1022.76'),
#   ('SYD', 'LAX', '2024-06-01', '1022.76'),
#   ('SYD', 'LAX', '2024-05-19', '1022.76'),
#   ('SYD', 'LAX', '2024-06-10', '1022.76'),
#   ('SYD', 'LAX', '2024-02-15', '1022.76'),
#   ('SYD', 'LAX', '2024-02-05', '1022.76'),
#   ('SYD', 'LAX', '2024-06-02', '1022.76'),
#   ('SYD', 'LAX', '2024-05-02', '1022.76'),
#   ('SYD', 'LAX', '2024-05-08', '1022.76'),
#   ('SYD', 'LAX', '2024-06-06', '1022.76'),
#   ('SYD', 'LAX', '2024-02-07', '1022.76'),
#   ('SYD', 'LAX', '2024-06-08', '1022.76'),
#   ('SYD', 'LAX', '2024-05-17', '1022.76'),
#   ('SYD', 'LAX', '2024-05-22', '1022.76'),
#   ('SYD', 'LAX', '2024-05-06', '1022.76'),
#   ('SYD', 'LAX', '2024-02-01', '1022.76'),
#   ('SYD', 'LAX', '2024-02-02', '1022.76'),
#   ('SYD', 'LAX', '2024-03-18', '1022.76'),
#   ('SYD', 'LAX', '2024-06-09', '1022.76'),
#   ('SYD', 'LAX', '2024-06-15', '1022.76'),
#   ('SYD', 'LAX', '2024-05-25', '1022.76'),
#   ('SYD', 'LAX', '2024-05-09', '1022.76'),
#   ('SYD', 'LAX', '2024-04-05', '1022.76'),
#   ('SYD', 'LAX', '2024-02-09', '1022.76'),
#   ('SYD', 'LAX', '2024-02-22', '1022.76'),
#   ('SYD', 'LAX', '2024-04-02', '1022.76'),
#   ('SYD', 'LAX', '2024-03-01', '1022.76'),
#   ('SYD', 'LAX', '2024-03-08', '1022.76'),
#   ('SYD', 'LAX', '2024-03-15', '1022.76'),
#   ('SYD', 'LAX', '2024-04-04', '1022.76'),
#   ('SYD', 'LAX', '2024-06-03', '1022.76'),
#   ('SYD', 'LAX', '2024-03-12', '1022.76'),
#   ('SYD', 'LAX', '2024-06-16', '1022.76'),
#   ('SYD', 'LAX', '2024-05-04', '1022.76'),
#   ('SYD', 'LAX', '2024-05-20', '1022.76'),
#   ('SYD', 'LAX', '2024-03-11', '1022.76'),
#   ('SYD', 'LAX', '2024-05-11', '1022.76'),
#   ('SYD', 'LAX', '2024-05-29', '1022.76'),
#   ('SYD', 'LAX', '2024-02-21', '1022.76'),
#   ('SYD', 'LAX', '2024-03-10', '1022.76'),
#   ('SYD', 'LAX', '2024-04-06', '1022.76'),
#   ('SYD', 'LAX', '2024-02-24', '1022.76'),
#   ('SYD', 'LAX', '2024-03-16', '1022.76'),
#   ('SYD', 'LAX', '2024-04-26', '1022.76'),
#   ('SYD', 'LAX', '2024-04-30', '1022.76'),
#   ('SYD', 'LAX', '2024-05-05', '1022.76'),
#   ('SYD', 'LAX', '2024-03-13', '1022.76'),
#   ('SYD', 'LAX', '2024-05-01', '1022.76'),
#   ('SYD', 'LAX', '2024-05-10', '1022.76'),
#   ('SYD', 'LAX', '2024-05-16', '1022.76'),
#   ('SYD', 'LAX', '2024-05-12', '1022.76'),
#   ('SYD', 'LAX', '2024-05-30', '1022.76'),
#   ('SYD', 'LAX', '2024-05-23', '1022.76'),
#   ('SYD', 'LAX', '2024-02-14', '1022.76'),
#   ('SYD', 'LAX', '2024-03-06', '1022.76'),
#   ('SYD', 'LAX', '2024-06-07', '1022.76'),
#   ('SYD', 'LAX', '2024-06-11', '1022.76'),
#   ('SYD', 'LAX', '2024-05-27', '1022.76'),
#   ('SYD', 'LAX', '2024-06-18', '1022.76'),
#   ('SYD', 'LAX', '2024-02-16', '1022.76'),
#   ('SYD', 'LAX', '2024-04-29', '1022.76'),
#   ('SYD', 'LAX', '2024-06-17', '1022.76'),
#   ('SYD', 'LAX', '2024-04-01', '1022.76'),
#   ('SYD', 'LAX', '2024-03-03', '1022.76'),
#   ('SYD', 'LAX', '2024-02-06', '1022.76'),
#   ('SYD', 'LAX', '2024-02-08', '1022.76'),
#   ('SYD', 'LAX', '2024-02-13', '1022.76'),
#   ('SYD', 'LAX', '2024-03-31', '1022.76'),
#   ('SYD', 'LAX', '2024-02-27', '1022.76'),
#   ('SYD', 'LAX', '2024-03-05', '1022.76'),
#   ('SYD', 'LAX', '2024-03-14', '1022.76'),
#   ('SYD', 'LAX', '2024-03-17', '1022.76'),
#   ('SYD', 'LAX', '2024-03-19', '1022.76'),
#   ('SYD', 'LAX', '2024-02-19', '1022.76'),
#   ('SYD', 'LAX', '2024-02-26', '1022.76'),
#   ('SYD', 'LAX', '2024-06-22', '1121.76'),
#   ('SYD', 'LAX', '2024-06-23', '1121.76'),
#   ('SYD', 'LAX', '2024-06-26', '1121.76'),
#   ('SYD', 'LAX', '2024-06-24', '1121.76'),
#   ('SYD', 'LAX', '2024-06-21', '1121.76'),
#   ('SYD', 'LAX', '2024-06-27', '1121.76'),
#   ('SYD', 'LAX', '2024-06-25', '1121.76'),
#   ('SYD', 'ONT', '2024-02-25', '1212.86'),
#   ('SYD', 'ONT', '2024-03-26', '1212.86'),
#   ('SYD', 'LAX', '2024-03-02', '1212.86'),
#   ('SYD', 'LAX', '2024-03-21', '1221.46'),
#   ('SYD', 'LAX', '2024-04-22', '1270.46'),
#   ('SYD', 'LAX', '2024-03-25', '1270.46'),
#   ('SYD', 'LAX', '2024-03-29', '1272.76'),
#   ('SYD', 'LAX', '2024-03-30', '1272.76'),
#   ('SYD', 'LAX', '2024-03-28', '1272.76'),
#   ('SYD', 'LAX', '2024-03-27', '1272.76'),
#   ('SYD', 'LAX', '2024-03-20', '1272.76'),
#   ('SYD', 'LAX', '2024-05-24', '1281.76'),
#   ('SYD', 'LAX', '2024-04-24', '1281.76'),
#   ('SYD', 'LAX', '2024-03-22', '1296.46'),
#   ('SYD', 'LAX', '2024-03-23', '1296.46'),
#   ('SYD', 'LAX', '2024-03-24', '1296.46'),
#   ('SYD', 'LAX', '2024-04-17', '1345.46'),
#   ('SYD', 'LAX', '2024-04-18', '1345.46'),
#   ('SYD', 'LAX', '2024-04-23', '1345.46'),
#   ('SYD', 'LAX', '2024-04-19', '1345.46'),
#   ('SYD', 'LAX', '2024-04-20', '1345.46'),
#   ('SYD', 'LAX', '2024-04-21', '1345.46'),
#   ('SYD', 'LAX', '2024-02-29', '1353.86'),
#   ('SYD', 'LAX', '2024-04-08', '1420.46'),
#   ('SYD', 'LAX', '2024-04-15', '1420.46'),
#   ('SYD', 'LAX', '2024-02-28', '1428.86'),
#   ('SYD', 'LAX', '2024-04-10', '1477.86'),
#   ('SYD', 'LAX', '2024-02-23', '1485.46'),
#   ('SYD', 'LAX', '2024-04-09', '1495.46'),
#   ('SYD', 'LAX', '2024-04-11', '1495.46'),
#   ('SYD', 'LAX', '2024-04-16', '1495.46'),
#   ('SYD', 'LAX', '2024-04-12', '1495.46'),
#   ('SYD', 'LAX', '2024-04-07', '1505.51'),
#   ('SYD', 'LAX', '2024-06-20', '1531.46'),
#   ('SYD', 'LAX', '2024-06-19', '1539.86'),
#   ('SYD', 'LAX', '2024-04-13', '1558.46'),
#   ('SYD', 'LAX', '2024-06-28', '1606.46'),
#   ('SYD', 'LAX', '2024-04-14', '1645.46'),
#   ('SYD', 'LAX', '2024-06-30', '2132.00'),
#   ('SYD', 'LAX', '2024-06-29', '2180.36'),
#   ('SYD', 'LAX', '2024-07-01', '2180.36')],
#  [('SYD', 'LAX', '2024-02-10', '998.26'),
#   ('SYD', 'ONT', '2024-02-09', '1014.86'),
#   ('SYD', 'LAX', '2024-02-16', '1014.86'),
#   ('SYD', 'LAX', '2024-04-27', '1022.76'),
#   ('SYD', 'LAX', '2024-05-03', '1022.76'),
#   ('SYD', 'LAX', '2024-05-21', '1022.76'),
#   ('SYD', 'LAX', '2024-04-28', '1022.76'),
#   ('SYD', 'LAX', '2024-05-19', '1022.76'),
#   ('SYD', 'LAX', '2024-05-24', '1022.76'),
#   ('SYD', 'LAX', '2024-05-31', '1022.76'),
#   ('SYD', 'LAX', '2024-06-01', '1022.76'),
#   ('SYD', 'LAX', '2024-05-07', '1022.76'),
#   ('SYD', 'LAX', '2024-06-05', '1022.76'),
#   ('SYD', 'LAX', '2024-02-06', '1022.76'),
#   ('SYD', 'LAX', '2024-02-15', '1022.76'),
#   ('SYD', 'LAX', '2024-03-10', '1022.76'),
#   ('SYD', 'LAX', '2024-06-08', '1022.76'),
#   ('SYD', 'LAX', '2024-06-06', '1022.76'),
#   ('SYD', 'LAX', '2024-02-05', '1022.76'),
#   ('SYD', 'LAX', '2024-06-15', '1022.76'),
#   ('SYD', 'LAX', '2024-05-23', '1022.76'),
#   ('SYD', 'LAX', '2024-04-02', '1022.76'),
#   ('SYD', 'LAX', '2024-06-02', '1022.76'),
#   ('SYD', 'LAX', '2024-03-08', '1022.76'),
#   ('SYD', 'LAX', '2024-05-04', '1022.76'),
#   ('SYD', 'LAX', '2024-05-11', '1022.76'),
#   ('SYD', 'LAX', '2024-05-25', '1022.76'),
#   ('SYD', 'LAX', '2024-02-17', '1022.76'),
#   ('SYD', 'LAX', '2024-04-24', '1022.76'),
#   ('SYD', 'LAX', '2024-04-25', '1022.76'),
#   ('SYD', 'LAX', '2024-05-02', '1022.76'),
#   ('SYD', 'LAX', '2024-05-06', '1022.76'),
#   ('SYD', 'LAX', '2024-05-08', '1022.76'),
#   ('SYD', 'LAX', '2024-05-13', '1022.76'),
#   ('SYD', 'LAX', '2024-05-14', '1022.76'),
#   ('SYD', 'LAX', '2024-05-16', '1022.76'),
#   ('SYD', 'LAX', '2024-05-17', '1022.76'),
#   ('SYD', 'LAX', '2024-05-20', '1022.76'),
#   ('SYD', 'LAX', '2024-05-22', '1022.76'),
#   ('SYD', 'LAX', '2024-05-29', '1022.76'),
#   ('SYD', 'LAX', '2024-06-10', '1022.76'),
#   ('SYD', 'LAX', '2024-06-12', '1022.76'),
#   ('SYD', 'LAX', '2024-06-13', '1022.76'),
#   ('SYD', 'LAX', '2024-06-14', '1022.76'),
#   ('SYD', 'LAX', '2024-04-03', '1022.76'),
#   ('SYD', 'LAX', '2024-05-12', '1022.76'),
#   ('SYD', 'LAX', '2024-05-26', '1022.76'),
#   ('SYD', 'LAX', '2024-02-02', '1022.76'),
#   ('SYD', 'LAX', '2024-02-08', '1022.76'),
#   ('SYD', 'LAX', '2024-02-12', '1022.76'),
#   ('SYD', 'LAX', '2024-02-21', '1022.76'),
#   ('SYD', 'LAX', '2024-03-06', '1022.76'),
#   ('SYD', 'LAX', '2024-03-07', '1022.76'),
#   ('SYD', 'LAX', '2024-03-11', '1022.76'),
#   ('SYD', 'LAX', '2024-06-09', '1022.76'),
#   ('SYD', 'LAX', '2024-03-15', '1022.76'),
#   ('SYD', 'LAX', '2024-03-03', '1022.76'),
#   ('SYD', 'LAX', '2024-06-16', '1022.76'),
#   ('SYD', 'LAX', '2024-05-18', '1022.76'),
#   ('SYD', 'LAX', '2024-02-14', '1022.76'),
#   ('SYD', 'LAX', '2024-02-04', '1022.76'),
#   ('SYD', 'LAX', '2024-04-06', '1022.76'),
#   ('SYD', 'LAX', '2024-02-03', '1022.76'),
#   ('SYD', 'LAX', '2024-03-09', '1022.76'),
#   ('SYD', 'LAX', '2024-05-10', '1022.76'),
#   ('SYD', 'LAX', '2024-05-28', '1022.76'),
#   ('SYD', 'LAX', '2024-02-20', '1022.76'),
#   ('SYD', 'LAX', '2024-03-02', '1022.76'),
#   ('SYD', 'LAX', '2024-04-26', '1022.76'),
#   ('SYD', 'LAX', '2024-02-11', '1022.76'),
#   ('SYD', 'LAX', '2024-03-16', '1022.76'),
#   ('SYD', 'LAX', '2024-06-03', '1022.76'),
#   ('SYD', 'LAX', '2024-04-29', '1022.76'),
#   ('SYD', 'LAX', '2024-05-30', '1022.76'),
#   ('SYD', 'LAX', '2024-03-14', '1022.76'),
#   ('SYD', 'LAX', '2024-04-30', '1022.76'),
#   ('SYD', 'LAX', '2024-06-04', '1022.76'),
#   ('SYD', 'LAX', '2024-05-01', '1022.76'),
#   ('SYD', 'LAX', '2024-05-09', '1022.76'),
#   ('SYD', 'LAX', '2024-05-15', '1022.76'),
#   ('SYD', 'LAX', '2024-02-01', '1022.76'),
#   ('SYD', 'LAX', '2024-03-04', '1022.76'),
#   ('SYD', 'LAX', '2024-03-18', '1022.76'),
#   ('SYD', 'LAX', '2024-05-27', '1022.76'),
#   ('SYD', 'LAX', '2024-06-11', '1022.76'),
#   ('SYD', 'LAX', '2024-06-07', '1022.76'),
#   ('SYD', 'LAX', '2024-06-17', '1022.76'),
#   ('SYD', 'LAX', '2024-04-01', '1022.76'),
#   ('SYD', 'LAX', '2024-04-04', '1022.76'),
#   ('SYD', 'LAX', '2024-03-12', '1022.76'),
#   ('SYD', 'LAX', '2024-04-05', '1022.76'),
#   ('SYD', 'LAX', '2024-05-05', '1022.76'),
#   ('SYD', 'LAX', '2024-02-07', '1022.76'),
#   ('SYD', 'LAX', '2024-02-13', '1022.76'),
#   ('SYD', 'LAX', '2024-02-19', '1022.76'),
#   ('SYD', 'LAX', '2024-02-22', '1022.76'),
#   ('SYD', 'LAX', '2024-02-23', '1022.76'),
#   ('SYD', 'LAX', '2024-02-26', '1022.76'),
#   ('SYD', 'LAX', '2024-02-27', '1022.76'),
#   ('SYD', 'LAX', '2024-03-05', '1022.76'),
#   ('SYD', 'LAX', '2024-03-13', '1022.76'),
#   ('SYD', 'LAX', '2024-02-18', '1022.76'),
#   ('SYD', 'LAX', '2024-02-25', '1022.76'),
#   ('SYD', 'LAX', '2024-03-17', '1022.76'),
#   ('SYD', 'LAX', '2024-03-24', '1022.76'),
#   ('SYD', 'LAX', '2024-03-31', '1022.76'),
#   ('SYD', 'LAX', '2024-06-22', '1121.76'),
#   ('SYD', 'LAX', '2024-06-23', '1121.76'),
#   ('SYD', 'LAX', '2024-06-25', '1121.76'),
#   ('SYD', 'LAX', '2024-06-20', '1121.76'),
#   ('SYD', 'LAX', '2024-06-21', '1121.76'),
#   ('SYD', 'LAX', '2024-06-24', '1121.76'),
#   ('SYD', 'LAX', '2024-06-26', '1121.76'),
#   ('SYD', 'LAX', '2024-06-27', '1121.76'),
#   ('SYD', 'LAX', '2024-03-20', '1221.46'),
#   ('SYD', 'LAX', '2024-03-21', '1221.46'),
#   ('SYD', 'LAX', '2024-03-01', '1231.76'),
#   ('SYD', 'LAX', '2024-04-18', '1270.46'),
#   ('SYD', 'LAX', '2024-03-29', '1272.76'),
#   ('SYD', 'LAX', '2024-03-30', '1272.76'),
#   ('SYD', 'LAX', '2024-03-28', '1272.76'),
#   ('SYD', 'LAX', '2024-03-25', '1272.76'),
#   ('SYD', 'LAX', '2024-03-26', '1272.76'),
#   ('SYD', 'LAX', '2024-03-27', '1272.76'),
#   ('SYD', 'LAX', '2024-03-19', '1272.76'),
#   ('SYD', 'LAX', '2024-04-23', '1281.76'),
#   ('SYD', 'LAX', '2024-06-28', '1292.86'),
#   ('SYD', 'LAX', '2024-03-22', '1296.46'),
#   ('SYD', 'LAX', '2024-03-23', '1296.46'),
#   ('SYD', 'LAX', '2024-04-17', '1345.46'),
#   ('SYD', 'LAX', '2024-04-22', '1345.46'),
#   ('SYD', 'LAX', '2024-04-19', '1345.46'),
#   ('SYD', 'LAX', '2024-04-20', '1345.46'),
#   ('SYD', 'LAX', '2024-04-21', '1345.46'),
#   ('SYD', 'LAX', '2024-02-29', '1353.86'),
#   ('SYD', 'LAX', '2024-02-28', '1353.86'),
#   ('SYD', 'LAX', '2024-02-24', '1387.04'),
#   ('SYD', 'LAX', '2024-04-11', '1420.46'),
#   ('SYD', 'LAX', '2024-04-10', '1469.46'),
#   ('SYD', 'LAX', '2024-04-09', '1477.86'),
#   ('SYD', 'LAX', '2024-04-16', '1477.86'),
#   ('SYD', 'LAX', '2024-06-19', '1483.46'),
#   ('SYD', 'LAX', '2024-04-08', '1495.46'),
#   ('SYD', 'LAX', '2024-04-15', '1495.46'),
#   ('SYD', 'LAX', '2024-04-12', '1495.46'),
#   ('SYD', 'LAX', '2024-04-14', '1495.46'),
#   ('SYD', 'LAX', '2024-06-18', '1495.46'),
#   ('SYD', 'LAX', '2024-04-07', '1645.46'),
#   ('SYD', 'LAX', '2024-04-13', '1708.46'),
#   ('SYD', 'ONT', '2024-07-01', '2131.80'),
#   ('SYD', 'LAX', '2024-06-29', '2180.36'),
#   ('SYD', 'LAX', '2024-06-30', '2206.76')],
#  [('SYD', 'ONT', '2024-02-09', '998.26'),
#   ('SYD', 'LAX', '2024-02-16', '998.26'),
#   ('SYD', 'ONT', '2024-02-08', '1014.86'),
#   ('SYD', 'LAX', '2024-02-10', '1014.86'),
#   ('SYD', 'LAX', '2024-02-13', '1014.86'),
#   ('SYD', 'ONT', '2024-06-02', '1014.86'),
#   ('SYD', 'LAX', '2024-05-03', '1022.76'),
#   ('SYD', 'LAX', '2024-06-01', '1022.76'),
#   ('SYD', 'LAX', '2024-05-11', '1022.76'),
#   ('SYD', 'LAX', '2024-05-25', '1022.76'),
#   ('SYD', 'LAX', '2024-04-23', '1022.76'),
#   ('SYD', 'LAX', '2024-04-24', '1022.76'),
#   ('SYD', 'LAX', '2024-04-25', '1022.76'),
#   ('SYD', 'LAX', '2024-04-28', '1022.76'),
#   ('SYD', 'LAX', '2024-05-07', '1022.76'),
#   ('SYD', 'LAX', '2024-05-10', '1022.76'),
#   ('SYD', 'LAX', '2024-05-12', '1022.76'),
#   ('SYD', 'LAX', '2024-05-13', '1022.76'),
#   ('SYD', 'LAX', '2024-05-15', '1022.76'),
#   ('SYD', 'LAX', '2024-05-16', '1022.76'),
#   ('SYD', 'LAX', '2024-05-19', '1022.76'),
#   ('SYD', 'LAX', '2024-05-21', '1022.76'),
#   ('SYD', 'LAX', '2024-05-22', '1022.76'),
#   ('SYD', 'LAX', '2024-05-26', '1022.76'),
#   ('SYD', 'LAX', '2024-05-28', '1022.76'),
#   ('SYD', 'LAX', '2024-05-29', '1022.76'),
#   ('SYD', 'LAX', '2024-06-10', '1022.76'),
#   ('SYD', 'LAX', '2024-06-12', '1022.76'),
#   ('SYD', 'LAX', '2024-06-13', '1022.76'),
#   ('SYD', 'LAX', '2024-06-14', '1022.76'),
#   ('SYD', 'LAX', '2024-04-03', '1022.76'),
#   ('SYD', 'LAX', '2024-02-01', '1022.76'),
#   ('SYD', 'LAX', '2024-02-07', '1022.76'),
#   ('SYD', 'LAX', '2024-02-15', '1022.76'),
#   ('SYD', 'LAX', '2024-02-20', '1022.76'),
#   ('SYD', 'LAX', '2024-03-06', '1022.76'),
#   ('SYD', 'LAX', '2024-03-07', '1022.76'),
#   ('SYD', 'LAX', '2024-03-10', '1022.76'),
#   ('SYD', 'LAX', '2024-03-11', '1022.76'),
#   ('SYD', 'LAX', '2024-05-24', '1022.76'),
#   ('SYD', 'LAX', '2024-05-31', '1022.76'),
#   ('SYD', 'LAX', '2024-06-09', '1022.76'),
#   ('SYD', 'LAX', '2024-04-29', '1022.76'),
#   ('SYD', 'LAX', '2024-03-14', '1022.76'),
#   ('SYD', 'LAX', '2024-03-24', '1022.76'),
#   ('SYD', 'LAX', '2024-04-02', '1022.76'),
#   ('SYD', 'LAX', '2024-04-27', '1022.76'),
#   ('SYD', 'LAX', '2024-06-08', '1022.76'),
#   ('SYD', 'LAX', '2024-02-03', '1022.76'),
#   ('SYD', 'LAX', '2024-05-17', '1022.76'),
#   ('SYD', 'LAX', '2024-06-15', '1022.76'),
#   ('SYD', 'LAX', '2024-05-09', '1022.76'),
#   ('SYD', 'LAX', '2024-03-01', '1022.76'),
#   ('SYD', 'LAX', '2024-03-08', '1022.76'),
#   ('SYD', 'LAX', '2024-02-02', '1022.76'),
#   ('SYD', 'LAX', '2024-03-15', '1022.76'),
#   ('SYD', 'LAX', '2024-06-16', '1022.76'),
#   ('SYD', 'LAX', '2024-05-04', '1022.76'),
#   ('SYD', 'LAX', '2024-05-14', '1022.76'),
#   ('SYD', 'LAX', '2024-06-06', '1022.76'),
#   ('SYD', 'LAX', '2024-05-18', '1022.76'),
#   ('SYD', 'LAX', '2024-03-23', '1022.76'),
#   ('SYD', 'LAX', '2024-05-02', '1022.76'),
#   ('SYD', 'LAX', '2024-05-20', '1022.76'),
#   ('SYD', 'LAX', '2024-02-17', '1022.76'),
#   ('SYD', 'LAX', '2024-02-12', '1022.76'),
#   ('SYD', 'LAX', '2024-02-21', '1022.76'),
#   ('SYD', 'LAX', '2024-03-04', '1022.76'),
#   ('SYD', 'LAX', '2024-02-24', '1022.76'),
#   ('SYD', 'LAX', '2024-06-04', '1022.76'),
#   ('SYD', 'LAX', '2024-03-02', '1022.76'),
#   ('SYD', 'LAX', '2024-04-26', '1022.76'),
#   ('SYD', 'LAX', '2024-05-01', '1022.76'),
#   ('SYD', 'LAX', '2024-02-11', '1022.76'),
#   ('SYD', 'LAX', '2024-03-05', '1022.76'),
#   ('SYD', 'LAX', '2024-03-09', '1022.76'),
#   ('SYD', 'LAX', '2024-05-06', '1022.76'),
#   ('SYD', 'LAX', '2024-02-05', '1022.76'),
#   ('SYD', 'LAX', '2024-02-14', '1022.76'),
#   ('SYD', 'LAX', '2024-03-16', '1022.76'),
#   ('SYD', 'LAX', '2024-04-30', '1022.76'),
#   ('SYD', 'LAX', '2024-05-05', '1022.76'),
#   ('SYD', 'LAX', '2024-06-03', '1022.76'),
#   ('SYD', 'LAX', '2024-05-08', '1022.76'),
#   ('SYD', 'LAX', '2024-06-05', '1022.76'),
#   ('SYD', 'LAX', '2024-02-04', '1022.76'),
#   ('SYD', 'LAX', '2024-05-23', '1022.76'),
#   ('SYD', 'LAX', '2024-05-27', '1022.76'),
#   ('SYD', 'LAX', '2024-05-30', '1022.76'),
#   ('SYD', 'LAX', '2024-06-07', '1022.76'),
#   ('SYD', 'LAX', '2024-06-11', '1022.76'),
#   ('SYD', 'LAX', '2024-04-01', '1022.76'),
#   ('SYD', 'LAX', '2024-04-04', '1022.76'),
#   ('SYD', 'LAX', '2024-04-05', '1022.76'),
#   ('SYD', 'LAX', '2024-02-22', '1022.76'),
#   ('SYD', 'LAX', '2024-02-06', '1022.76'),
#   ('SYD', 'LAX', '2024-02-18', '1022.76'),
#   ('SYD', 'LAX', '2024-02-19', '1022.76'),
#   ('SYD', 'LAX', '2024-02-25', '1022.76'),
#   ('SYD', 'LAX', '2024-02-26', '1022.76'),
#   ('SYD', 'LAX', '2024-02-27', '1022.76'),
#   ('SYD', 'LAX', '2024-03-03', '1022.76'),
#   ('SYD', 'LAX', '2024-03-17', '1022.76'),
#   ('SYD', 'LAX', '2024-03-12', '1022.76'),
#   ('SYD', 'LAX', '2024-03-13', '1022.76'),
#   ('SYD', 'LAX', '2024-03-31', '1022.76'),
#   ('SYD', 'LAX', '2024-06-22', '1121.76'),
#   ('SYD', 'LAX', '2024-06-23', '1121.76'),
#   ('SYD', 'LAX', '2024-06-19', '1121.76'),
#   ('SYD', 'LAX', '2024-06-25', '1121.76'),
#   ('SYD', 'LAX', '2024-06-20', '1121.76'),
#   ('SYD', 'LAX', '2024-06-21', '1121.76'),
#   ('SYD', 'LAX', '2024-06-24', '1121.76'),
#   ('SYD', 'LAX', '2024-06-26', '1121.76'),
#   ('SYD', 'LAX', '2024-03-26', '1221.46'),
#   ('SYD', 'LAX', '2024-03-19', '1221.46'),
#   ('SYD', 'LAX', '2024-03-20', '1221.46'),
#   ('SYD', 'LAX', '2024-03-21', '1221.46'),
#   ('SYD', 'LAX', '2024-06-27', '1226.26'),
#   ('SYD', 'LAX', '2024-04-17', '1270.46'),
#   ('SYD', 'LAX', '2024-04-18', '1270.46'),
#   ('SYD', 'LAX', '2024-03-27', '1270.46'),
#   ('SYD', 'LAX', '2024-03-29', '1272.76'),
#   ('SYD', 'LAX', '2024-03-30', '1272.76'),
#   ('SYD', 'LAX', '2024-03-28', '1272.76'),
#   ('SYD', 'LAX', '2024-03-25', '1272.76'),
#   ('SYD', 'LAX', '2024-03-18', '1272.76'),
#   ('SYD', 'LAX', '2024-06-28', '1292.86'),
#   ('SYD', 'LAX', '2024-03-22', '1296.46'),
#   ('SYD', 'LAX', '2024-04-06', '1331.76'),
#   ('SYD', 'LAX', '2024-04-19', '1345.46'),
#   ('SYD', 'LAX', '2024-04-20', '1345.46'),
#   ('SYD', 'LAX', '2024-04-22', '1345.46'),
#   ('SYD', 'LAX', '2024-02-29', '1353.86'),
#   ('SYD', 'LAX', '2024-02-28', '1353.86'),
#   ('SYD', 'LAX', '2024-02-23', '1387.04'),
#   ('SYD', 'LAX', '2024-04-21', '1420.46'),
#   ('SYD', 'LAX', '2024-06-18', '1420.46'),
#   ('SYD', 'LAX', '2024-04-11', '1420.46'),
#   ('SYD', 'LAX', '2024-04-10', '1455.51'),
#   ('SYD', 'LAX', '2024-04-09', '1469.46'),
#   ('SYD', 'LAX', '2024-04-16', '1469.46'),
#   ('SYD', 'LAX', '2024-04-08', '1477.86'),
#   ('SYD', 'LAX', '2024-04-15', '1477.86'),
#   ('SYD', 'LAX', '2024-06-17', '1495.46'),
#   ('SYD', 'LAX', '2024-04-13', '1558.46'),
#   ('SYD', 'LAX', '2024-04-14', '1570.46'),
#   ('SYD', 'LAX', '2024-04-12', '1615.26'),
#   ('SYD', 'LAX', '2024-04-07', '1653.93'),
#   ('SYD', 'ONT', '2024-07-01', '2131.80'),
#   ('SYD', 'LAX', '2024-06-30', '2131.80'),
#   ('SYD', 'LAX', '2024-06-29', '2206.76')],
#  [('SYD', 'ONT', '2024-02-08', '998.26'),
#   ('SYD', 'ONT', '2024-02-09', '1014.86'),
#   ('SYD', 'LAX', '2024-02-15', '1014.86'),
#   ('SYD', 'LAX', '2024-04-27', '1022.76'),
#   ('SYD', 'LAX', '2024-06-01', '1022.76'),
#   ('SYD', 'LAX', '2024-05-29', '1022.76'),
#   ('SYD', 'LAX', '2024-02-12', '1022.76'),
#   ('SYD', 'LAX', '2024-02-02', '1022.76'),
#   ('SYD', 'LAX', '2024-06-02', '1022.76'),
#   ('SYD', 'LAX', '2024-06-08', '1022.76'),
#   ('SYD', 'LAX', '2024-05-04', '1022.76'),
#   ('SYD', 'LAX', '2024-05-11', '1022.76'),
#   ('SYD', 'LAX', '2024-05-18', '1022.76'),
#   ('SYD', 'LAX', '2024-05-25', '1022.76'),
#   ('SYD', 'LAX', '2024-02-10', '1022.76'),
#   ('SYD', 'LAX', '2024-03-09', '1022.76'),
#   ('SYD', 'LAX', '2024-03-23', '1022.76'),
#   ('SYD', 'LAX', '2024-04-23', '1022.76'),
#   ('SYD', 'LAX', '2024-04-24', '1022.76'),
#   ('SYD', 'LAX', '2024-04-25', '1022.76'),
#   ('SYD', 'LAX', '2024-04-28', '1022.76'),
#   ('SYD', 'LAX', '2024-05-02', '1022.76'),
#   ('SYD', 'LAX', '2024-05-06', '1022.76'),
#   ('SYD', 'LAX', '2024-05-12', '1022.76'),
#   ('SYD', 'LAX', '2024-05-14', '1022.76'),
#   ('SYD', 'LAX', '2024-05-15', '1022.76'),
#   ('SYD', 'LAX', '2024-05-20', '1022.76'),
#   ('SYD', 'LAX', '2024-05-21', '1022.76'),
#   ('SYD', 'LAX', '2024-05-22', '1022.76'),
#   ('SYD', 'LAX', '2024-05-28', '1022.76'),
#   ('SYD', 'LAX', '2024-06-10', '1022.76'),
#   ('SYD', 'LAX', '2024-06-12', '1022.76'),
#   ('SYD', 'LAX', '2024-06-13', '1022.76'),
#   ('SYD', 'LAX', '2024-05-10', '1022.76'),
#   ('SYD', 'LAX', '2024-02-06', '1022.76'),
#   ('SYD', 'LAX', '2024-02-14', '1022.76'),
#   ('SYD', 'LAX', '2024-03-04', '1022.76'),
#   ('SYD', 'LAX', '2024-03-06', '1022.76'),
#   ('SYD', 'LAX', '2024-03-10', '1022.76'),
#   ('SYD', 'LAX', '2024-06-09', '1022.76'),
#   ('SYD', 'LAX', '2024-02-25', '1022.76'),
#   ('SYD', 'LAX', '2024-03-24', '1022.76'),
#   ('SYD', 'LAX', '2024-06-15', '1022.76'),
#   ('SYD', 'LAX', '2024-04-02', '1022.76'),
#   ('SYD', 'LAX', '2024-05-03', '1022.76'),
#   ('SYD', 'LAX', '2024-05-13', '1022.76'),
#   ('SYD', 'LAX', '2024-06-05', '1022.76'),
#   ('SYD', 'LAX', '2024-05-24', '1022.76'),
#   ('SYD', 'LAX', '2024-05-31', '1022.76'),
#   ('SYD', 'LAX', '2024-03-01', '1022.76'),
#   ('SYD', 'LAX', '2024-03-31', '1022.76'),
#   ('SYD', 'LAX', '2024-03-22', '1022.76'),
#   ('SYD', 'LAX', '2024-05-16', '1022.76'),
#   ('SYD', 'LAX', '2024-05-19', '1022.76'),
#   ('SYD', 'LAX', '2024-05-17', '1022.76'),
#   ('SYD', 'LAX', '2024-03-11', '1022.76'),
#   ('SYD', 'LAX', '2024-03-08', '1022.76'),
#   ('SYD', 'LAX', '2024-04-03', '1022.76'),
#   ('SYD', 'LAX', '2024-02-04', '1022.76'),
#   ('SYD', 'LAX', '2024-02-07', '1022.76'),
#   ('SYD', 'LAX', '2024-02-21', '1022.76'),
#   ('SYD', 'LAX', '2024-02-16', '1022.76'),
#   ('SYD', 'LAX', '2024-03-15', '1022.76'),
#   ('SYD', 'LAX', '2024-02-03', '1022.76'),
#   ('SYD', 'LAX', '2024-05-07', '1022.76'),
#   ('SYD', 'LAX', '2024-06-06', '1022.76'),
#   ('SYD', 'LAX', '2024-02-17', '1022.76'),
#   ('SYD', 'LAX', '2024-02-05', '1022.76'),
#   ('SYD', 'LAX', '2024-02-24', '1022.76'),
#   ('SYD', 'LAX', '2024-03-02', '1022.76'),
#   ('SYD', 'LAX', '2024-03-16', '1022.76'),
#   ('SYD', 'LAX', '2024-04-29', '1022.76'),
#   ('SYD', 'LAX', '2024-04-30', '1022.76'),
#   ('SYD', 'LAX', '2024-03-13', '1022.76'),
#   ('SYD', 'LAX', '2024-05-01', '1022.76'),
#   ('SYD', 'LAX', '2024-04-26', '1022.76'),
#   ('SYD', 'LAX', '2024-05-05', '1022.76'),
#   ('SYD', 'LAX', '2024-06-03', '1022.76'),
#   ('SYD', 'LAX', '2024-04-04', '1022.76'),
#   ('SYD', 'LAX', '2024-05-08', '1022.76'),
#   ('SYD', 'LAX', '2024-05-26', '1022.76'),
#   ('SYD', 'LAX', '2024-06-14', '1022.76'),
#   ('SYD', 'LAX', '2024-02-01', '1022.76'),
#   ('SYD', 'LAX', '2024-03-07', '1022.76'),
#   ('SYD', 'LAX', '2024-05-09', '1022.76'),
#   ('SYD', 'LAX', '2024-05-23', '1022.76'),
#   ('SYD', 'LAX', '2024-05-27', '1022.76'),
#   ('SYD', 'LAX', '2024-06-11', '1022.76'),
#   ('SYD', 'LAX', '2024-05-30', '1022.76'),
#   ('SYD', 'LAX', '2024-06-04', '1022.76'),
#   ('SYD', 'LAX', '2024-04-01', '1022.76'),
#   ('SYD', 'LAX', '2024-02-19', '1022.76'),
#   ('SYD', 'LAX', '2024-06-07', '1022.76'),
#   ('SYD', 'LAX', '2024-02-11', '1022.76'),
#   ('SYD', 'LAX', '2024-02-13', '1022.76'),
#   ('SYD', 'LAX', '2024-02-18', '1022.76'),
#   ('SYD', 'LAX', '2024-02-20', '1022.76'),
#   ('SYD', 'LAX', '2024-02-26', '1022.76'),
#   ('SYD', 'LAX', '2024-02-27', '1022.76'),
#   ('SYD', 'LAX', '2024-03-03', '1022.76'),
#   ('SYD', 'LAX', '2024-03-05', '1022.76'),
#   ('SYD', 'LAX', '2024-03-12', '1022.76'),
#   ('SYD', 'LAX', '2024-03-14', '1022.76'),
#   ('SYD', 'LAX', '2024-02-23', '1022.76'),
#   ('SYD', 'LAX', '2024-06-22', '1121.76'),
#   ('SYD', 'LAX', '2024-06-23', '1121.76'),
#   ('SYD', 'LAX', '2024-06-18', '1121.76'),
#   ('SYD', 'LAX', '2024-06-19', '1121.76'),
#   ('SYD', 'LAX', '2024-06-20', '1121.76'),
#   ('SYD', 'LAX', '2024-06-21', '1121.76'),
#   ('SYD', 'LAX', '2024-06-24', '1121.76'),
#   ('SYD', 'LAX', '2024-06-25', '1121.76'),
#   ('SYD', 'ONT', '2024-02-22', '1164.86'),
#   ('SYD', 'LAX', '2024-06-26', '1217.86'),
#   ('SYD', 'LAX', '2024-03-25', '1221.46'),
#   ('SYD', 'LAX', '2024-03-26', '1221.46'),
#   ('SYD', 'LAX', '2024-03-18', '1221.46'),
#   ('SYD', 'LAX', '2024-03-19', '1221.46'),
#   ('SYD', 'LAX', '2024-03-20', '1221.46'),
#   ('SYD', 'LAX', '2024-03-21', '1221.46'),
#   ('SYD', 'LAX', '2024-06-27', '1226.26'),
#   ('SYD', 'LAX', '2024-04-17', '1270.46'),
#   ('SYD', 'LAX', '2024-04-18', '1270.46'),
#   ('SYD', 'LAX', '2024-04-22', '1270.46'),
#   ('SYD', 'LAX', '2024-03-29', '1272.76'),
#   ('SYD', 'LAX', '2024-03-30', '1272.76'),
#   ('SYD', 'LAX', '2024-03-27', '1272.76'),
#   ('SYD', 'LAX', '2024-03-28', '1272.76'),
#   ('SYD', 'LAX', '2024-03-17', '1272.76'),
#   ('SYD', 'LAX', '2024-04-05', '1331.76'),
#   ('SYD', 'LAX', '2024-04-19', '1345.46'),
#   ('SYD', 'LAX', '2024-02-29', '1353.86'),
#   ('SYD', 'LAX', '2024-02-28', '1353.86'),
#   ('SYD', 'LAX', '2024-06-28', '1367.86'),
#   ('SYD', 'LAX', '2024-04-09', '1420.46'),
#   ('SYD', 'LAX', '2024-04-16', '1420.46'),
#   ('SYD', 'LAX', '2024-04-20', '1420.46'),
#   ('SYD', 'LAX', '2024-04-21', '1420.46'),
#   ('SYD', 'LAX', '2024-06-17', '1420.46'),
#   ('SYD', 'LAX', '2024-04-08', '1469.46'),
#   ('SYD', 'LAX', '2024-04-10', '1469.46'),
#   ('SYD', 'LAX', '2024-04-15', '1469.46'),
#   ('SYD', 'LAX', '2024-04-11', '1469.46'),
#   ('SYD', 'LAX', '2024-04-12', '1495.46'),
#   ('SYD', 'LAX', '2024-04-06', '1541.76'),
#   ('SYD', 'LAX', '2024-04-14', '1570.46'),
#   ('SYD', 'LAX', '2024-06-16', '1570.46'),
#   ('SYD', 'LAX', '2024-04-13', '1633.46'),
#   ('SYD', 'LAX', '2024-04-07', '1653.93'),
#   ('SYD', 'ONT', '2024-07-01', '2131.80'),
#   ('SYD', 'LAX', '2024-06-30', '2131.80'),
#   ('SYD', 'LAX', '2024-06-29', '2206.76')],
#  [('SYD', 'ONT', '2024-02-08', '1014.86'),
#   ('SYD', 'LAX', '2024-02-16', '1014.86'),
#   ('SYD', 'LAX', '2024-02-13', '1014.86'),
#   ('SYD', 'LAX', '2024-02-06', '1014.86'),
#   ('SYD', 'LAX', '2024-04-27', '1022.76'),
#   ('SYD', 'LAX', '2024-05-03', '1022.76'),
#   ('SYD', 'LAX', '2024-06-01', '1022.76'),
#   ('SYD', 'LAX', '2024-06-08', '1022.76'),
#   ('SYD', 'LAX', '2024-03-22', '1022.76'),
#   ('SYD', 'LAX', '2024-03-08', '1022.76'),
#   ('SYD', 'LAX', '2024-05-11', '1022.76'),
#   ('SYD', 'LAX', '2024-03-09', '1022.76'),
#   ('SYD', 'LAX', '2024-03-23', '1022.76'),
#   ('SYD', 'LAX', '2024-04-23', '1022.76'),
#   ('SYD', 'LAX', '2024-04-24', '1022.76'),
#   ('SYD', 'LAX', '2024-05-08', '1022.76'),
#   ('SYD', 'LAX', '2024-05-10', '1022.76'),
#   ('SYD', 'LAX', '2024-05-13', '1022.76'),
#   ('SYD', 'LAX', '2024-05-14', '1022.76'),
#   ('SYD', 'LAX', '2024-05-17', '1022.76'),
#   ('SYD', 'LAX', '2024-05-19', '1022.76'),
#   ('SYD', 'LAX', '2024-05-20', '1022.76'),
#   ('SYD', 'LAX', '2024-05-21', '1022.76'),
#   ('SYD', 'LAX', '2024-05-22', '1022.76'),
#   ('SYD', 'LAX', '2024-05-26', '1022.76'),
#   ('SYD', 'LAX', '2024-06-10', '1022.76'),
#   ('SYD', 'LAX', '2024-06-12', '1022.76'),
#   ('SYD', 'LAX', '2024-05-16', '1022.76'),
#   ('SYD', 'LAX', '2024-02-05', '1022.76'),
#   ('SYD', 'LAX', '2024-02-14', '1022.76'),
#   ('SYD', 'LAX', '2024-03-04', '1022.76'),
#   ('SYD', 'LAX', '2024-03-11', '1022.76'),
#   ('SYD', 'LAX', '2024-05-24', '1022.76'),
#   ('SYD', 'LAX', '2024-05-31', '1022.76'),
#   ('SYD', 'LAX', '2024-06-02', '1022.76'),
#   ('SYD', 'LAX', '2024-05-04', '1022.76'),
#   ('SYD', 'LAX', '2024-02-03', '1022.76'),
#   ('SYD', 'LAX', '2024-05-29', '1022.76'),
#   ('SYD', 'LAX', '2024-06-14', '1022.76'),
#   ('SYD', 'LAX', '2024-04-03', '1022.76'),
#   ('SYD', 'LAX', '2024-02-12', '1022.76'),
#   ('SYD', 'LAX', '2024-02-20', '1022.76'),
#   ('SYD', 'LAX', '2024-02-15', '1022.76'),
#   ('SYD', 'LAX', '2024-06-09', '1022.76'),
#   ('SYD', 'LAX', '2024-04-29', '1022.76'),
#   ('SYD', 'LAX', '2024-05-30', '1022.76'),
#   ('SYD', 'LAX', '2024-02-25', '1022.76'),
#   ('SYD', 'LAX', '2024-03-24', '1022.76'),
#   ('SYD', 'LAX', '2024-04-02', '1022.76'),
#   ('SYD', 'LAX', '2024-03-01', '1022.76'),
#   ('SYD', 'LAX', '2024-03-15', '1022.76'),
#   ('SYD', 'LAX', '2024-05-18', '1022.76'),
#   ('SYD', 'LAX', '2024-05-15', '1022.76'),
#   ('SYD', 'LAX', '2024-04-25', '1022.76'),
#   ('SYD', 'LAX', '2024-03-10', '1022.76'),
#   ('SYD', 'LAX', '2024-03-07', '1022.76'),
#   ('SYD', 'LAX', '2024-03-21', '1022.76'),
#   ('SYD', 'LAX', '2024-05-25', '1022.76'),
#   ('SYD', 'LAX', '2024-02-17', '1022.76'),
#   ('SYD', 'LAX', '2024-04-28', '1022.76'),
#   ('SYD', 'LAX', '2024-05-07', '1022.76'),
#   ('SYD', 'LAX', '2024-06-13', '1022.76'),
#   ('SYD', 'LAX', '2024-03-06', '1022.76'),
#   ('SYD', 'LAX', '2024-02-10', '1022.76'),
#   ('SYD', 'LAX', '2024-02-24', '1022.76'),
#   ('SYD', 'LAX', '2024-06-07', '1022.76'),
#   ('SYD', 'LAX', '2024-03-02', '1022.76'),
#   ('SYD', 'LAX', '2024-04-26', '1022.76'),
#   ('SYD', 'LAX', '2024-05-01', '1022.76'),
#   ('SYD', 'LAX', '2024-03-05', '1022.76'),
#   ('SYD', 'LAX', '2024-04-30', '1022.76'),
#   ('SYD', 'LAX', '2024-05-05', '1022.76'),
#   ('SYD', 'LAX', '2024-03-12', '1022.76'),
#   ('SYD', 'LAX', '2024-05-06', '1022.76'),
#   ('SYD', 'LAX', '2024-06-05', '1022.76'),
#   ('SYD', 'LAX', '2024-02-02', '1022.76'),
#   ('SYD', 'LAX', '2024-05-12', '1022.76'),
#   ('SYD', 'LAX', '2024-05-02', '1022.76'),
#   ('SYD', 'LAX', '2024-05-27', '1022.76'),
#   ('SYD', 'LAX', '2024-06-11', '1022.76'),
#   ('SYD', 'LAX', '2024-02-18', '1022.76'),
#   ('SYD', 'LAX', '2024-05-28', '1022.76'),
#   ('SYD', 'LAX', '2024-06-06', '1022.76'),
#   ('SYD', 'LAX', '2024-02-01', '1022.76'),
#   ('SYD', 'LAX', '2024-06-03', '1022.76'),
#   ('SYD', 'LAX', '2024-06-04', '1022.76'),
#   ('SYD', 'LAX', '2024-04-01', '1022.76'),
#   ('SYD', 'LAX', '2024-03-03', '1022.76'),
#   ('SYD', 'LAX', '2024-05-09', '1022.76'),
#   ('SYD', 'LAX', '2024-05-23', '1022.76'),
#   ('SYD', 'LAX', '2024-02-09', '1022.76'),
#   ('SYD', 'LAX', '2024-02-04', '1022.76'),
#   ('SYD', 'LAX', '2024-02-11', '1022.76'),
#   ('SYD', 'LAX', '2024-02-19', '1022.76'),
#   ('SYD', 'LAX', '2024-02-23', '1022.76'),
#   ('SYD', 'LAX', '2024-02-26', '1022.76'),
#   ('SYD', 'LAX', '2024-03-13', '1022.76'),
#   ('SYD', 'LAX', '2024-03-31', '1022.76'),
#   ('SYD', 'LAX', '2024-02-22', '1022.76'),
#   ('SYD', 'LAX', '2024-03-14', '1022.76'),
#   ('SYD', 'LAX', '2024-06-22', '1121.76'),
#   ('SYD', 'LAX', '2024-06-23', '1121.76'),
#   ('SYD', 'LAX', '2024-06-17', '1121.76'),
#   ('SYD', 'LAX', '2024-06-18', '1121.76'),
#   ('SYD', 'LAX', '2024-06-19', '1121.76'),
#   ('SYD', 'LAX', '2024-06-21', '1121.76'),
#   ('SYD', 'LAX', '2024-06-20', '1121.76'),
#   ('SYD', 'LAX', '2024-06-24', '1121.76'),
#   ('SYD', 'LAX', '2024-06-25', '1217.86'),
#   ('SYD', 'LAX', '2024-06-26', '1217.86'),
#   ('SYD', 'LAX', '2024-03-25', '1221.46'),
#   ('SYD', 'LAX', '2024-03-26', '1221.46'),
#   ('SYD', 'LAX', '2024-03-18', '1221.46'),
#   ('SYD', 'LAX', '2024-03-19', '1221.46'),
#   ('SYD', 'LAX', '2024-03-20', '1221.46'),
#   ('SYD', 'LAX', '2024-02-07', '1221.46'),
#   ('SYD', 'LAX', '2024-02-27', '1231.76'),
#   ('SYD', 'LAX', '2024-04-17', '1270.46'),
#   ('SYD', 'LAX', '2024-04-18', '1270.46'),
#   ('SYD', 'LAX', '2024-04-22', '1270.46'),
#   ('SYD', 'LAX', '2024-03-27', '1270.46'),
#   ('SYD', 'LAX', '2024-03-29', '1272.76'),
#   ('SYD', 'LAX', '2024-03-30', '1272.76'),
#   ('SYD', 'LAX', '2024-03-28', '1272.76'),
#   ('SYD', 'LAX', '2024-03-16', '1272.76'),
#   ('SYD', 'LAX', '2024-03-17', '1272.76'),
#   ('SYD', 'LAX', '2024-04-06', '1281.76'),
#   ('SYD', 'LAX', '2024-04-21', '1281.76'),
#   ('SYD', 'LAX', '2024-06-27', '1301.26'),
#   ('SYD', 'LAX', '2024-02-21', '1312.04'),
#   ('SYD', 'LAX', '2024-04-04', '1331.76'),
#   ('SYD', 'LAX', '2024-02-28', '1353.86'),
#   ('SYD', 'LAX', '2024-06-28', '1367.86'),
#   ('SYD', 'LAX', '2024-04-08', '1390.51'),
#   ('SYD', 'LAX', '2024-04-09', '1420.46'),
#   ('SYD', 'LAX', '2024-04-15', '1420.46'),
#   ('SYD', 'LAX', '2024-04-16', '1420.46'),
#   ('SYD', 'LAX', '2024-04-11', '1420.46'),
#   ('SYD', 'LAX', '2024-04-19', '1420.46'),
#   ('SYD', 'LAX', '2024-04-20', '1420.46'),
#   ('SYD', 'LAX', '2024-02-29', '1428.86'),
#   ('SYD', 'LAX', '2024-04-10', '1455.51'),
#   ('SYD', 'LAX', '2024-06-16', '1495.46'),
#   ('SYD', 'LAX', '2024-04-05', '1541.76'),
#   ('SYD', 'LAX', '2024-04-12', '1570.46'),
#   ('SYD', 'LAX', '2024-04-14', '1570.46'),
#   ('SYD', 'LAX', '2024-06-15', '1570.46'),
#   ('SYD', 'LAX', '2024-04-07', '1603.93'),
#   ('SYD', 'LAX', '2024-04-13', '1633.46'),
#   ('SYD', 'ONT', '2024-07-01', '2131.80'),
#   ('SYD', 'LAX', '2024-06-30', '2131.80'),
#   ('SYD', 'LAX', '2024-06-29', '2206.76')]]

# %%
flat_list = [item for sublist in return_flight_results for item in sublist]

# Create a Pandas DataFrame
columns = ['origin', 'destination', 'departureDate', 'totalPrice']
df = pd.DataFrame(flat_list, columns=columns)

# %%
# Out:
# [{'type': 'flight-date',
#   'origin': 'SYD',
#   'destination': 'LAX',
#   'departureDate': '2024-03-13',
#   'price': {'total': '1356.38'},
#   'links': {'flightDestinations': 'https://test.api.amadeus.com/v1/shopping/flight-destinations?origin=SYD&departureDate=2024-01-13,2024-07-01&oneWay=true&nonStop=true&viewBy=DATE',
#    'flightOffers': 'https://test.api.amadeus.com/v2/shopping/flight-offers?originLocationCode=SYD&destinationLocationCode=LAX&departureDate=2024-03-13&adults=1&nonStop=true'}}]
